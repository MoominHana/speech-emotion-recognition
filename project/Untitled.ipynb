# %%
import pandas as pd
from scipy.io import wavfile

# %%
df = pd.read_csv('audio.csv')
df.set_index('File_Name', inplace=True)

# %%
df.head(20)
# Out:
#                           Actor Gender    length
# File_Name
# 03-01-01-01-01-01-01.wav      1      M  3.303292
# 03-01-01-01-01-02-01.wav      1      M  3.336667
# 03-01-01-01-02-01-01.wav      1      M  3.269917
# 03-01-01-01-02-02-01.wav      1      M  3.169833
# 03-01-02-01-01-01-01.wav      1      M  3.536854
# 03-01-02-01-01-02-01.wav      1      M  3.603583
# 03-01-02-01-02-01-01.wav      1      M  3.503500
# 03-01-02-01-02-02-01.wav      1      M  3.470146
# 03-01-02-02-01-01-01.wav      1      M  3.703708
# 03-01-02-02-01-02-01.wav      1      M  4.004000
# 03-01-02-02-02-01-01.wav      1      M  4.204208
# 03-01-02-02-02-02-01.wav      1      M  4.004000
# 03-01-03-01-01-01-01.wav      1      M  3.470146
# 03-01-03-01-01-02-01.wav      1      M  3.470125
# 03-01-03-01-02-01-01.wav      1      M  3.536854
# 03-01-03-01-02-02-01.wav      1      M  3.703708
# 03-01-03-02-01-01-01.wav      1      M  3.670333
# 03-01-03-02-01-02-01.wav      1      M  3.636958
# 03-01-03-02-02-01-01.wav      1      M  3.937250
# 03-01-03-02-02-02-01.wav      1      M  3.937271

# %%
for f in df.index:
    rate, signal = wavfile.read('data/'+f)
    df.at[f, 'length'] = signal.shape[0]/rate
# Out:
# C:\Users\barry\AppData\Local\Temp\ipykernel_4296\1458821718.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, signal = wavfile.read('data/'+f)
# C:\Users\barry\AppData\Local\Temp\ipykernel_4296\1458821718.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, signal = wavfile.read('data/'+f)
