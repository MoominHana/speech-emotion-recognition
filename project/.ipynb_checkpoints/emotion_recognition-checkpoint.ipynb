# %% [markdown]
# ## Imports

# %%
import pandas as pd
from scipy.io import wavfile
import seaborn as sns
import matplotlib.pyplot as plt
import parselmouth
import numpy as np
import os

# %% [markdown]
# ## Reading the Data

# %%
# Create DataFrame with index `File_Name`
df = pd.read_csv('audio.csv')
df.set_index('File_Name', inplace=True)

# %%
# Show current DF
df.head()
# Out:
#                           Actor Gender  Emotion Intensity  Statement  \
# File_Name
# 03-01-01-01-01-01-01.wav      1      M  neutral    normal          1
# 03-01-01-01-01-02-01.wav      1      M  neutral    normal          1
# 03-01-01-01-02-01-01.wav      1      M  neutral    normal          2
# 03-01-01-01-02-02-01.wav      1      M  neutral    normal          2
# 03-01-02-01-01-01-01.wav      1      M     calm    normal          1
#
#                           Repetition
# File_Name
# 03-01-01-01-01-01-01.wav           1
# 03-01-01-01-01-02-01.wav           2
# 03-01-01-01-02-01-01.wav           1
# 03-01-01-01-02-02-01.wav           2
# 03-01-02-01-01-01-01.wav           1

# %%
# Read WAV files into the DataFrame
for f in df.index:
    rate, signal = wavfile.read('data/'+f)
    # Measure length of each audio file
    df.at[f, 'length'] = signal.shape[0]/rate
# Out:
# C:\Users\Bea\AppData\Local\Temp\ipykernel_25836\2002995416.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, signal = wavfile.read('data/'+f)
# C:\Users\Bea\AppData\Local\Temp\ipykernel_25836\2002995416.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, signal = wavfile.read('data/'+f)

# %%
# Print all unique emotions in the dataset
print(df['Emotion'].unique())
print(df['Emotion'].value_counts())
# Out:
# ['neutral' 'calm' 'happy' 'sad' 'angry' 'fearful' 'disgust' 'surprised']
# Emotion
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Do we need to remove (unvoiced/silent) parts in each audio file

# %% [markdown]
# ## EDA

# %%
# Distribution of emotions in the dataset ✅
# What is the duration of the audio files 
# What are the key features extracted from the audio files? 
# How do the features vary across different emotions? 
# Are there any correlations between different features? 
# How do the feature distributions look? 
# What are the summary statistics for the features?** 
#    - Mean, median, standard deviation, etc., for each feature. 

# Are there any outliers in the data?** 
#    - How will you handle outliers in the feature set?

# %%
# Distribution of emotions in the dataset
sns.countplot(x='Emotion', data=df)
plt.show()

# %%
sns.countplot(x='Emotion', hue='Gender', data=df)
plt.show()

# %% [markdown]
# ## Model Preparation

# %% [markdown]
# ## Extra

# %%
emotion_counts = df['Emotion'].value_counts()

# %%
# Create a DataFrame with the counts of each emotion
emotion_counts = df['Emotion'].value_counts().reset_index()
emotion_counts.columns = ['Emotion', 'Count']

# # Plot using stripplot
# sns.stripplot(x='Emotion', y='Count', data=emotion_counts, jitter=True, dodge=True)
# plt.title('Emotion Counts')
# plt.show()

sns.boxplot(x ='Emotion', y ='Count', data = emotion_counts)
# Out:
# <Axes: xlabel='Emotion', ylabel='Count'>

# %%
# What is the duration of the audio files?
plt.figure(figsize=(10, 6))
sns.histplot(df['length'], bins=20, kde=True)
plt.title('Histogram of Audio File Durations')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
